# %%
# Importing packages.

import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt

# %matplotlib inline 

# Bringing in the data.

df = pd.read_csv(r'//Users/mirnessabanovic/Downloads/fetal_health.csv')

# %%
# Initial look at the data.

df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
# Checking the data for empty/missing values.
# Using a for loop to check percentage of data missing for each column. 

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# baseline value - 0%
# accelerations - 0%
# fetal_movement - 0%
# uterine_contractions - 0%
# light_decelerations - 0%
# severe_decelerations - 0%
# prolongued_decelerations - 0%
# abnormal_short_term_variability - 0%
# mean_value_of_short_term_variability - 0%
# percentage_of_time_with_abnormal_long_term_variability - 0%
# mean_value_of_long_term_variability - 0%
# histogram_width - 0%
# histogram_min - 0%
# histogram_max - 0%
# histogram_number_of_peaks - 0%
# histogram_number_of_zeroes - 0%
# histogram_mode - 0%
# histogram_mean - 0%
# histogram_median - 0%
# histogram_variance - 0%
# histogram_tendency - 0%
# fetal_health - 0%

# %%
# No missing or null values.

# %%
# Finding the data type for every column.

print(df.dtypes)
# Out:
# baseline value                                            float64
# accelerations                                             float64
# fetal_movement                                            float64
# uterine_contractions                                      float64
# light_decelerations                                       float64
# severe_decelerations                                      float64
# prolongued_decelerations                                  float64
# abnormal_short_term_variability                           float64
# mean_value_of_short_term_variability                      float64
# percentage_of_time_with_abnormal_long_term_variability    float64
# mean_value_of_long_term_variability                       float64
# histogram_width                                           float64
# histogram_min                                             float64
# histogram_max                                             float64
# ...

# %%
# Checking for outliers in the baseline fetal heart rate column.

df.boxplot(column=['baseline value'])
# Out:
# <AxesSubplot:>

# %%
# Checking for duplicate rows.

df[df.duplicated()]
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 68             140.0          0.007           0.000                 0.004
# 234            123.0          0.000           0.000                 0.000
# 306            145.0          0.000           0.020                 0.000
# 324            135.0          0.000           0.000                 0.000
# 333            144.0          0.000           0.019                 0.000
# 787            123.0          0.003           0.003                 0.000
# 791            123.0          0.003           0.004                 0.000
# 798            146.0          0.000           0.000                 0.003
# 849            138.0          0.002           0.000                 0.004
# 1113           122.0          0.000           0.000                 0.000
# 1114           122.0          0.000           0.000                 0.000
# 1115           122.0          0.000           0.000                 0.000
# ...

# %%
# Deleting duplicate rows.

df.drop_duplicates()
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
# Now, I will begin to look at what factors are most correlated with poor fetal health outcomes.

# I predict that pregnancies that have a high abnormal short-term and long-term heart rate variability 
# are also more likely to give birth to fetuses with pathological conditions.
# I also predict that fetuses that have high short-term and long-term heart rate variability will also have
# high baseline fetal heart rates.

# Scatter plot of short-term heart rate variability and baseline heart rate.

plt.scatter(x = df['abnormal_short_term_variability'], y = df ['baseline value'])

plt.title('Short Term Heart Rate Variability vs Baseline Heart Rate')

plt.xlabel('Short Term Heart Rate Variability')

plt.ylabel('Baseline Heart Rate')

plt.show()

# %%
# Scatter plot of long-term heart rate variability and baseline heart rate.

plt.scatter(x = df['percentage_of_time_with_abnormal_long_term_variability'], y = df ['baseline value'])

plt.title('Long Term Heart Rate Variability vs Baseline Heart Rate')

plt.xlabel('Long Term Heart Rate Variability')

plt.ylabel('Baseline Heart Rate')

plt.show()

# %%
# Here, I will use a regression plot to visualize the correlation between short-term heart rate variability 
# and baseline fetal heart rate.

sns.regplot(x = 'abnormal_short_term_variability', y ='baseline value', 
            data = df, scatter_kws = {"color": "red"}, line_kws = {"color":"blue"})
# Out:
# <AxesSubplot:xlabel='abnormal_short_term_variability', ylabel='baseline value'>

# %%
# A regression plot to visualize the correlation between long-term heart rate variability 
# and baseline fetal heart rate.

sns.regplot(x = 'percentage_of_time_with_abnormal_long_term_variability', y ='baseline value',
            data = df, scatter_kws = {"color": "red"}, line_kws = {"color":"blue"})
# Out:
# <AxesSubplot:xlabel='percentage_of_time_with_abnormal_long_term_variability', ylabel='baseline value'>

# %%
# There is a slight positive correlation between both short-term and long-term heart rate variability and
# baseline fetal heart rate.
# Here, I will create a correlation matrix to observe the relationship between all the variables in the table to 
# fetal health outcomes.

df.corr(method = 'pearson')
# Out:
#                                                     baseline value  \
# baseline value                                            1.000000
# accelerations                                            -0.080560
# fetal_movement                                           -0.033436
# uterine_contractions                                     -0.146373
# light_decelerations                                      -0.159032
# severe_decelerations                                     -0.053518
# prolongued_decelerations                                 -0.104597
# abnormal_short_term_variability                           0.305570
# mean_value_of_short_term_variability                     -0.279607
# percentage_of_time_with_abnormal_long_term_vari...        0.285630
# mean_value_of_long_term_variability                      -0.032091
# histogram_width                                          -0.147679
# histogram_min                                             0.361619
# ...

# %%
# Both short-term and long-term heart rate variability have a moderate correlation with fetal health outcomes.
# My prediction was correct.

# %%
# Visualizing the previous correlation matrix with a heat map for easier comprehension.

correlation_matrix = df.corr()

plt.subplots(figsize = (20,15))

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for Various Tests Taken During Pregnancy and Fetal Health Outcomes')

plt.xlabel('Pregnancy Tests')

plt.ylabel('Pregnancy Tests')
# Out:
# Text(158.09374999999997, 0.5, 'Pregnancy Tests')

# %%
# Correlation matrix between all columns in the table.

correlation_matrix = df.corr()

corr_pairs = correlation_matrix.unstack

corr_pairs
# Out:
# <bound method DataFrame.unstack of                                                     baseline value  \
# baseline value                                            1.000000
# accelerations                                            -0.080560
# fetal_movement                                           -0.033436
# uterine_contractions                                     -0.146373
# light_decelerations                                      -0.159032
# severe_decelerations                                     -0.053518
# prolongued_decelerations                                 -0.104597
# abnormal_short_term_variability                           0.305570
# mean_value_of_short_term_variability                     -0.279607
# percentage_of_time_with_abnormal_long_term_vari...        0.285630
# mean_value_of_long_term_variability                      -0.032091
# histogram_width                                          -0.147679
# ...

# %%
# Narrowing down the results of the correlation matrix to only include those with a moderate-high correlation (> 0.4).

strong_corr = sorted_pairs[abs(sorted_pairs) > 0.4]

print(strong_corr)
# Out:
#                                                     baseline value  \
# accelerations                                                  NaN
# histogram_mode                                            0.708993
# histogram_mean                                            0.723121
# mean_value_of_long_term_variability                            NaN
# histogram_median                                          0.789246
# uterine_contractions                                           NaN
# histogram_tendency                                             NaN
# mean_value_of_short_term_variability                           NaN
# histogram_width                                                NaN
# histogram_max                                                  NaN
# histogram_number_of_peaks                                      NaN
# histogram_number_of_zeroes                                     NaN
# light_decelerations                                            NaN
# ...

# %%
# My prediction was correct. Fetuses that have high short-term and long-term heart rate variability tend to have
# poor fetal health outcomes.
